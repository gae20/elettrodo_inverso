# %%
import torch

if torch.cuda.is_available():
    print(f"GPU disponibile: {torch.cuda.get_device_name(0)}")
else:
    print("GPU non disponibile. Sto usando la CPU.")
# Out:
# GPU non disponibile. Sto usando la CPU.

# %%
# !nvidia-smi
# Out:
# 234.41s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# /bin/bash: line 1: nvidia-smi: command not found

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("confusion_matrix_test.tiff")
plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 2456.5, 2704.5, -0.5)

# %%
img = Image.open("confusion_matrix_val.tiff")
plt.imshow(img)
plt.axis("off")
# Out:
# (-0.5, 2456.5, 2704.5, -0.5)
